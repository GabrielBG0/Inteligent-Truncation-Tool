# %%
import pandas as pd
ds = pd.read_csv('../../CSVs/new_dataset_predictions.csv', sep='§')
ds
# Out:
# C:\Users\gabre\AppData\Local\Temp\ipykernel_16924\1540664141.py:2: ParserWarning: Falling back to the 'python' engine because the separator encoded in utf-8 is > 1 char long, and the 'c' engine does not support such separators; you can avoid this warning by specifying engine='python'.
#   ds = pd.read_csv('../../CSVs/dataset_predictionsInt.csv', sep='§')
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\parsers\python_parser.py:760, in PythonParser._next_iter_line(self, row_num)
#     <a href='file:///c%3A/Users/gabre/AppData/Roaming/Python/Python38/site-packages/pandas/io/parsers/python_parser.py?line=758'>759</a> assert self.data is not None
# --> <a href='file:///c%3A/Users/gabre/AppData/Roaming/Python/Python38/site-packages/pandas/io/parsers/python_parser.py?line=759'>760</a> line = next(self.data)
# ...
